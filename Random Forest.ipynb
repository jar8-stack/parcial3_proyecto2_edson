# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # prellenado de variables numericas

# %%
tren_numerico= pd.read_csv('numeric_train.csv', engine='python')

# %%
tren_numerico.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]>

# %%
tren_numerico
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
tren_numerico1= tren_numerico
tren_numerico1.fillna(0)
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   0.0      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
tren_numerico2= tren_numerico.apply(lambda x: x.fillna(x.mean()), axis=0)
tren_numerico2
# Out:
#      PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare
# 0              1         0       3  22.000000      1      0   7.2500
# 1              2         1       1  38.000000      1      0  71.2833
# 2              3         1       3  26.000000      0      0   7.9250
# 3              4         1       1  35.000000      1      0  53.1000
# 4              5         0       3  35.000000      0      0   8.0500
# ..           ...       ...     ...        ...    ...    ...      ...
# 886          887         0       2  27.000000      0      0  13.0000
# 887          888         1       1  19.000000      0      0  30.0000
# 888          889         0       3  29.699118      1      2  23.4500
# 889          890         1       1  26.000000      0      0  30.0000
# 890          891         0       3  32.000000      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
tren_numerico3= tren_numerico.apply(lambda x: x.fillna(x.median()), axis=0)
tren_numerico3
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3  28.0      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
tren= pd.read_csv('train.csv', engine='python')
tren
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tren2= tren

# %%
tren2['Age']= tren_numerico3['Age']
tren2['Fare']= tren_numerico3['Fare']
tren2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # prellenado de variables categoricas

# %%
tren_categorico= tren
tren_categorico.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
tren_categorico
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tren_categorico['Cabin'].fillna("Desconocida", inplace=True)
tren_categorico
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tren_categorico['Embarked'].fillna("Desconocido", inplace=True)
tren_categorico
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tren2['Cabin']= tren_categorico['Cabin']
tren2['Embarked']= tren_categorico['Embarked']
tren2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Prellenando las variables de testeo numericas

# %%
tren_test= pd.read_csv('test.csv', engine='python')

# %%
tren_test.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
tren_test_numeric= tren_test.drop(['Name', 'Sex', 'Cabin', 'Embarked', 'Ticket'], axis=1)
tren_test_numeric
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare
# 0            892         0       3  34.5      0      0    7.8292
# 1            893         1       3  47.0      1      0    7.0000
# 2            894         0       2  62.0      0      0    9.6875
# 3            895         0       3  27.0      0      0    8.6625
# 4            896         1       3  22.0      1      1   12.2875
# ..           ...       ...     ...   ...    ...    ...       ...
# 413         1305         0       3   NaN      0      0    8.0500
# 414         1306         1       1  39.0      0      0  108.9000
# 415         1307         0       3  38.5      0      0    7.2500
# 416         1308         0       3   NaN      0      0    8.0500
# 417         1309         0       3   NaN      1      1   22.3583
#
# [418 rows x 7 columns]

# %%
tren_test_numeric1= tren_test_numeric
tren_test_numeric1.fillna(0)
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare
# 0            892         0       3  34.5      0      0    7.8292
# 1            893         1       3  47.0      1      0    7.0000
# 2            894         0       2  62.0      0      0    9.6875
# 3            895         0       3  27.0      0      0    8.6625
# 4            896         1       3  22.0      1      1   12.2875
# ..           ...       ...     ...   ...    ...    ...       ...
# 413         1305         0       3   0.0      0      0    8.0500
# 414         1306         1       1  39.0      0      0  108.9000
# 415         1307         0       3  38.5      0      0    7.2500
# 416         1308         0       3   0.0      0      0    8.0500
# 417         1309         0       3   0.0      1      1   22.3583
#
# [418 rows x 7 columns]

# %%
tren_test_numeric2= tren_test_numeric.apply(lambda x: x.fillna(x.median()), axis=0)
tren_test_numeric2
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare
# 0            892         0       3  34.5      0      0    7.8292
# 1            893         1       3  47.0      1      0    7.0000
# 2            894         0       2  62.0      0      0    9.6875
# 3            895         0       3  27.0      0      0    8.6625
# 4            896         1       3  22.0      1      1   12.2875
# ..           ...       ...     ...   ...    ...    ...       ...
# 413         1305         0       3  27.0      0      0    8.0500
# 414         1306         1       1  39.0      0      0  108.9000
# 415         1307         0       3  38.5      0      0    7.2500
# 416         1308         0       3  27.0      0      0    8.0500
# 417         1309         0       3  27.0      1      1   22.3583
#
# [418 rows x 7 columns]

# %%
tren_test['Age']= tren_test_numeric2['Age']
tren_test['Fare']= tren_test_numeric2['Fare']
tren_test
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # Prellenando las variables de testeo categoricas

# %%
tren_test_categoric= tren_test
tren_test_categoric.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
tren_test_categoric
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
tren_test_categoric['Cabin'].fillna("Desconocido", inplace=True)
tren_test_categoric['Embarked'].fillna("Desconocido", inplace=True)
tren_test_categoric
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
tren_test['Cabin']= tren_test_categoric['Cabin']
tren_test['Embarked']= tren_test_categoric['Embarked']
tren_test
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # Empezando el algoritmo Random Forest

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Variables de procesamiento

# %%
tren2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tren_test
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#Preparamos los datos de entrenamiento.
sex = pd.get_dummies(tren2['Sex'],drop_first=True)
#cabin = pd.get_dummies(tren2['Cabin'],drop_first=True)
embarked = pd.get_dummies(tren2['Embarked'],drop_first=True)

# %%
tren2.drop(['Sex','Embarked','Name','Ticket', 'Cabin'],axis=1,inplace=True)
tren2 = pd.concat([tren2,sex,embarked],axis=1)
tren2 #Datos de entrenamiento
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  male  \
# 0              1         0       3  22.0      1      0   7.2500     1
# 1              2         1       1  38.0      1      0  71.2833     0
# 2              3         1       3  26.0      0      0   7.9250     0
# 3              4         1       1  35.0      1      0  53.1000     0
# 4              5         0       3  35.0      0      0   8.0500     1
# ..           ...       ...     ...   ...    ...    ...      ...   ...
# 886          887         0       2  27.0      0      0  13.0000     1
# 887          888         1       1  19.0      0      0  30.0000     0
# 888          889         0       3  28.0      1      2  23.4500     0
# 889          890         1       1  26.0      0      0  30.0000     1
# 890          891         0       3  32.0      0      0   7.7500     1
#
#      Desconocido  Q  S
# 0              0  0  1
# 1              0  0  0
# 2              0  0  1
# 3              0  0  1
# ...

# %%
#Preparamos los datos para testeo
sex = pd.get_dummies(tren_test['Sex'],drop_first=True)
#cabin = pd.get_dummies(tren_test['Cabin'],drop_first=True)
embarked = pd.get_dummies(tren_test['Embarked'],drop_first=True)

# %%
tren_test.drop(['Sex','Embarked','Name','Ticket', 'Cabin'],axis=1,inplace=True)
tren_test = pd.concat([tren_test,sex,embarked],axis=1)
tren_test #Datos de testeo
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare  male  Q  S
# 0            892         0       3  34.5      0      0    7.8292     1  1  0
# 1            893         1       3  47.0      1      0    7.0000     0  0  1
# 2            894         0       2  62.0      0      0    9.6875     1  1  0
# 3            895         0       3  27.0      0      0    8.6625     1  0  1
# 4            896         1       3  22.0      1      1   12.2875     0  0  1
# ..           ...       ...     ...   ...    ...    ...       ...   ... .. ..
# 413         1305         0       3  27.0      0      0    8.0500     1  0  1
# 414         1306         1       1  39.0      0      0  108.9000     0  0  0
# 415         1307         0       3  38.5      0      0    7.2500     1  0  1
# 416         1308         0       3  27.0      0      0    8.0500     1  0  1
# 417         1309         0       3  27.0      1      1   22.3583     1  0  0
#
# [418 rows x 10 columns]

# %%
X_train= tren2.drop(['Survived','Desconocido'],axis='columns')
Y_train= tren2.Survived

# %%
X_test = tren_test.drop('Survived',axis='columns')
Y_test = tren_test.Survived

# %%
X_test
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch      Fare  male  Q  S
# 0            892       3  34.5      0      0    7.8292     1  1  0
# 1            893       3  47.0      1      0    7.0000     0  0  1
# 2            894       2  62.0      0      0    9.6875     1  1  0
# 3            895       3  27.0      0      0    8.6625     1  0  1
# 4            896       3  22.0      1      1   12.2875     0  0  1
# ..           ...     ...   ...    ...    ...       ...   ... .. ..
# 413         1305       3  27.0      0      0    8.0500     1  0  1
# 414         1306       1  39.0      0      0  108.9000     0  0  0
# 415         1307       3  38.5      0      0    7.2500     1  0  1
# 416         1308       3  27.0      0      0    8.0500     1  0  1
# 417         1309       3  27.0      1      1   22.3583     1  0  0
#
# [418 rows x 9 columns]

# %%
X_train
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0              1       3  22.0      1      0   7.2500     1  0  1
# 1              2       1  38.0      1      0  71.2833     0  0  0
# 2              3       3  26.0      0      0   7.9250     0  0  1
# 3              4       1  35.0      1      0  53.1000     0  0  1
# 4              5       3  35.0      0      0   8.0500     1  0  1
# ..           ...     ...   ...    ...    ...      ...   ... .. ..
# 886          887       2  27.0      0      0  13.0000     1  0  1
# 887          888       1  19.0      0      0  30.0000     0  0  1
# 888          889       3  28.0      1      2  23.4500     0  0  1
# 889          890       1  26.0      0      0  30.0000     1  0  0
# 890          891       3  32.0      0      0   7.7500     1  1  0
#
# [891 rows x 9 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(X_test, Y_test)
# Out:
# 0.7918660287081339

# %%
Y_predicted = model.predict(X_test)

# %%
#Matriz de confusion
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, Y_predicted)
cm
# Out:
# array([[217,  49],
#        [ 38, 114]], dtype=int64)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
from sklearn import tree
model.estimators_
# Out:
# [DecisionTreeClassifier(max_features='auto', random_state=981296312),
#  DecisionTreeClassifier(max_features='auto', random_state=1374081774),
#  DecisionTreeClassifier(max_features='auto', random_state=1874589791),
#  DecisionTreeClassifier(max_features='auto', random_state=1001742408),
#  DecisionTreeClassifier(max_features='auto', random_state=1953621072),
#  DecisionTreeClassifier(max_features='auto', random_state=545507978),
#  DecisionTreeClassifier(max_features='auto', random_state=978777929),
#  DecisionTreeClassifier(max_features='auto', random_state=518046171),
#  DecisionTreeClassifier(max_features='auto', random_state=1513883491),
#  DecisionTreeClassifier(max_features='auto', random_state=81595224),
#  DecisionTreeClassifier(max_features='auto', random_state=1929327219),
#  DecisionTreeClassifier(max_features='auto', random_state=886707214),
#  DecisionTreeClassifier(max_features='auto', random_state=1420690006),
# ...

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(model.estimators_[2],filled=True)
# Out:
# [Text(328.28237704918035, 527.6117647058824, 'X[1] <= 2.5\ngini = 0.478\nsamples = 563\nvalue = [540, 351]'),
#  Text(97.33555327868852, 495.63529411764705, 'X[2] <= 17.5\ngini = 0.485\nsamples = 253\nvalue = [174, 246]'),
#  Text(27.442622950819672, 463.6588235294118, 'X[0] <= 787.0\ngini = 0.089\nsamples = 24\nvalue = [2, 41]'),
#  Text(16.465573770491805, 431.6823529411765, 'X[0] <= 303.0\ngini = 0.053\nsamples = 20\nvalue = [1, 36]'),
#  Text(10.97704918032787, 399.7058823529412, 'X[5] <= 96.565\ngini = 0.153\nsamples = 7\nvalue = [1, 11]'),
#  Text(5.488524590163935, 367.7294117647059, 'gini = 0.0\nsamples = 6\nvalue = [0, 11]'),
#  Text(16.465573770491805, 367.7294117647059, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(21.95409836065574, 399.7058823529412, 'gini = 0.0\nsamples = 13\nvalue = [0, 25]'),
#  Text(38.41967213114754, 431.6823529411765, 'X[4] <= 0.5\ngini = 0.278\nsamples = 4\nvalue = [1, 5]'),
# ...
